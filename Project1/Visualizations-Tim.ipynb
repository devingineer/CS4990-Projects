# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('data/candy-data.csv')
display(df.head())
# Out:
#   competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0      100 Grand          1       0        1               0       0
# 1   3 Musketeers          1       0        0               0       1
# 2       One dime          0       0        0               0       0
# 3    One quarter          0       0        0               0       0
# 4      Air Heads          0       1        0               0       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0                 1     0    1         0         0.732         0.860
# 1                 0     0    1         0         0.604         0.511
# 2                 0     0    0         0         0.011         0.116
# 3                 0     0    0         0         0.011         0.511
# 4                 0     0    0         0         0.906         0.511
#
#    winpercent
# 0   66.971725
# 1   67.602936
# 2   32.261086
# 3   46.116505
# 4   52.341465

# %%
# Identify candy type columns
candy_type_columns = ['chocolate', 'fruity', 'caramel', 'peanutyalmondy', 'nougat', 'crispedricewafer', 'hard', 'bar', 'pluribus']

# Dictionary to store average popularity for each candy type
popularity_by_candy_type = {}

# Calculate average winpercent for each candy type
for col in candy_type_columns:
    # Filter the DataFrame to include only candies of the current type (where the column value is 1)
    type_df = df[df[col] == 1]
    if not type_df.empty:
        popularity_by_candy_type[col] = type_df['winpercent'].mean()

# Convert the results to a DataFrame for better display
popularity_df = pd.DataFrame(popularity_by_candy_type.items(), columns=['Candy Type', 'Average Winpercent'])
popularity_df = popularity_df.sort_values(by='Average Winpercent', ascending=False).reset_index(drop=True)

display(popularity_df)
# Out:
#          Candy Type  Average Winpercent
# 0  crispedricewafer           66.170252
# 1    peanutyalmondy           63.697137
# 2               bar           61.295413
# 3         chocolate           60.921529
# 4            nougat           60.051879
# 5           caramel           57.346908
# 6          pluribus           46.822781
# 7            fruity           44.119741
# 8              hard           40.508982

# %%
fig2, ax1 = plt.subplots(figsize=(10, 6))
ax1.bar(popularity_df['Candy Type'], popularity_df['Average Winpercent'], color='blue') # Use specific columns and a basic color
ax1.set_title('Average Candy Popularity by Type') # Corrected title
ax1.set_xlabel('Candy Type') # Corrected x-axis label
ax1.set_ylabel('Average Winpercent')
ax1.set_ylim(0, 100)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Remove all "lines": no grid, no spines, no tick marks
ax1.grid(False)
for spine in ax1.spines.values():
    spine.set_visible(False)
ax1.tick_params(axis="both", length=0)

plt.tight_layout() # Adjust layout to prevent labels from being cut off
plt.savefig('figures/Tim-Figure1.png', bbox_inches='tight')
plt.show()

# %%
# Create a bar chart with lines
fig2, ax2 = plt.subplots(figsize=(10, 6))
ax2.bar(popularity_df['Candy Type'], popularity_df['Average Winpercent'], color='blue') # Use specific columns and a basic color
ax2.set_title('Average Candy Popularity by Type') # Corrected title
ax2.set_xlabel('Candy Type') # Corrected x-axis label
ax2.set_ylabel('Average Winpercent')
ax2.set_ylim(0, 100)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Remove all "lines": no grid, no spines, no tick marks
ax2.grid(False)
for spine in ax2.spines.values():
    spine.set_visible(False)
ax2.tick_params(axis="both", length=0)

ax2.grid(True, axis="y", linestyle="--", alpha=0.5)

plt.tight_layout() # Adjust layout to prevent labels from being cut off
plt.savefig('figures/Tim-Figure2.png', bbox_inches='tight')
plt.show()

# %%
# Create a bar chart with lines
fig3, ax3 = plt.subplots(figsize=(10, 6))
ax3.bar(popularity_df['Candy Type'], popularity_df['Average Winpercent'], color='blue') # Use specific columns and a basic color
ax3.set_title('Average Candy Popularity by Type') # Corrected title
ax3.set_xlabel('Candy Type') # Corrected x-axis label
ax3.set_ylabel('Average Winpercent')
ax3.set_ylim(0, 100)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Remove all "lines": no grid, no spines, no tick marks
ax3.grid(False)
for spine in ax3.spines.values():
    spine.set_visible(False)
ax3.tick_params(axis="both", length=0)

# Add vertical grid lines
ax3.grid(True, axis="x", linestyle='-', alpha=0.5)

plt.tight_layout() # Adjust layout to prevent labels from being cut off
plt.savefig('figures/Tim-Figure3.png', bbox_inches='tight')
plt.show()
